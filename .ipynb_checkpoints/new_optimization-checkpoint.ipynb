# %%
import pandas as pd
import numpy as np

# Load data
loans = pd.read_csv('loans_filtered.csv')

# %%
R_MAX = 0.18          # Maximum APR (constraint)
#default_rate = 0.06

def calculate_present_value(row):
    """Calculate the present value of monthly payments for a loan"""
    term = int(row['term'])          # Loan term in months
    installment = row['installment'] # Monthly payment amount
    monthly_discount = 1 + R_MAX / 12  # Monthly discount factor
    #p = 1 - ((1 - default_rate) ** (1/12))
    
    total_pv = 0.0
    for t in range(1, term + 1):
        #total_pv += installment * ((1 - p) ** t) / (monthly_discount ** t)
        total_pv += installment / (monthly_discount ** t)
    return total_pv

# Calculate present value for each loan
loans['present_value'] = loans.apply(calculate_present_value, axis=1)

# %%
FEE_MIN = 0.03        # Minimum origination fee rate
FEE_MAX = 0.08        # Maximum origination fee rate

loans["min_required_pv"] = loans["loan_amount"] * (1 - FEE_MAX)
infeasible_mask = loans["present_value"] < loans["min_required_pv"]
infeasible_loans = loans[infeasible_mask]
feasible_loans = loans[~infeasible_mask].copy()

print(f"Excluded {len(infeasible_loans)} loans violating minimum PV requirement:")
if len(infeasible_loans) > 0:
    print(infeasible_loans[["loan_amount", "term", "installment", "present_value", "min_required_pv"]])
else:
    print("(None)")
# Out:
# Excluded 6169 loans violating minimum PV requirement:
#       loan_amount  term  installment  present_value  min_required_pv
# 0           28000    60       652.53   25696.806856          25760.0
# 3           21600    36       664.19   18371.949912          19872.0
# 5            5000    36       153.75    4252.830213           4600.0
# 6           24000    60       553.35   21791.071788          22080.0
# 7           20000    60       444.79   17515.949798          18400.0
# ...           ...   ...          ...            ...              ...
# 9993         5000    36       156.62    4332.216377           4600.0
# 9994         4800    36       155.81    4309.811222           4416.0
# 9995        24000    36       744.90   20604.443743          22080.0
# 9998        24000    36       722.76   19992.036193          22080.0
# 9999        12800    36       418.52   11576.549598          11776.0
#
# [6169 rows x 5 columns]

# %%
import pulp
feasible_loans = feasible_loans[feasible_loans['debt_to_income_final'] <= 36]
N = len(feasible_loans)

# New risk score created for each loan
feasible_loans['risk_score'] = (
    0.6 * loans['grade'].map({'A':1.5, 'B':1.3, 'C':1.1, 'D':0.9, 'E':0.7, 'F':0.5, 'G':0.3}) +  # Grade weight
    0.4 * feasible_loans['interest_rate']                    # Interest rate weight
)

# --- 3. Define PuLP Problem ---
prob = pulp.LpProblem("Origination_Fee_Optimization", pulp.LpMaximize)

# Decision variables: origination fees (0.03 <= f_i <= 0.08)
f = pulp.LpVariable.dicts("fee", range(N), lowBound= FEE_MIN, upBound=FEE_MAX)
L = feasible_loans['loan_amount'].values

# Objective: Maximize sum(f_i * L_i)
#prob += pulp.lpSum([f[i] * feasible_loans['loan_amount'].iloc[i] for i in range(N)])

# Objective: Maximize sum(f_i * L_i) - 0.1 * risk_score * sum(f_i * L_i)
prob += pulp.lpSum([f[i] * L[i] for i in range(N)]) - 0.1 * pulp.lpSum([f[i] * L[i] * feasible_loans['risk_score'].iloc[i] for i in range(N)])

# Constraints
for i in range(N):
    # PV_i >= L_i * (1 - f_i)
    prob += feasible_loans['loan_amount'].iloc[i] * (1 - f[i]) <= feasible_loans['present_value'].iloc[i], f"PV_constraint_{i}"

    # Fee linked to interest rate: f_i >= 0.2 * r_i
    prob += f[i] >= 0.2 * (feasible_loans['interest_rate'].iloc[i] / 100), f"Interest_rate_constraint_{i}"

prob += pulp.lpSum(f) / N <= 0.055, "Average_Fee_Constraint"

# %%
# --- 4. Solve ---
prob.solve()

# --- 5. Results ---
if pulp.LpStatus[prob.status] == 'Optimal':
    optimal_fees = [f[i].varValue for i in range(N)]
    total_revenue = sum(optimal_fees[i] * feasible_loans['loan_amount'].iloc[i] for i in range(N))
    print("Optimal origination fees:", optimal_fees)
    print("Total revenue:", total_revenue)
else:
    print("Optimization failed. Status:", pulp.LpStatus[prob.status])
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/alanwang/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/_4/t03mdfy94ts0ylt8cw0q1bp00000gn/T/e05f32ac667641acaf7e2e509dbc29a2-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/_4/t03mdfy94ts0ylt8cw0q1bp00000gn/T/e05f32ac667641acaf7e2e509dbc29a2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7390 COLUMNS
# At line 22159 RHS
# At line 29545 BOUNDS
# At line 36930 ENDATA
# Problem MODEL has 7385 rows, 3692 columns and 11076 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1 (-7384) rows, 3398 (-294) columns and 3398 (-7678) elements
# 0  Obj 671156.24 Dual inf 14308137 (3398)
# 2  Obj 900644.35
# Optimal - objective value 900644.35
# After Postsolve, objective 900644.35, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 900644.3509 - 2 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Optimal origination fees: [0.07314579, 0.03418, 0.08, 0.08, 0.03806, 0.03806, 0.05744, 0.05354, 0.08, 0.073044368, 0.03806, 0.04078, 0.0429, 0.08, 0.08, 0.03612, 0.08, 0.040450861, 0.040420127, 0.04582, 0.06158, 0.08, 0.03494, 0.073165907, 0.073035147, 0.03494, 0.08, 0.03884, 0.073021317, 0.03494, 0.03204, 0.08, 0.073050953, 0.062303291, 0.07314579, 0.08, 0.04582, 0.03612, 0.04, 0.040445922, 0.05354, 0.060112998, 0.040589165, 0.053543585, 0.060089947, 0.08, 0.08, 0.03612, 0.03204, 0.08, 0.08, 0.03202, 0.04776, 0.040358659, 0.0429, 0.05164, 0.040450861, 0.03418, 0.03202, 0.08, 0.0429, 0.0437, 0.03612, 0.03418, 0.08, 0.08, 0.08, 0.03494, 0.060117608, 0.08, 0.03612, 0.041921814, 0.03806, 0.060117608, 0.060089947, 0.03204, 0.03884, 0.08, 0.08, 0.03806, 0.08, 0.040450861, 0.08, 0.03612, 0.03494, 0.053534365, 0.040589165, 0.072998266, 0.08, 0.0429, 0.03884, 0.0
08, 0.03202, 0.08, 0.041913858, 0.08, 0.04776, 0.073045922, 0.0429, 0.06229954, 0.0369, 0.060248008, 0.08, 0.05354, 0.073182671, 0.0429, 0.040450861, 0.0429, 0.0369, 0.08, 0.04, 0.041924388, 0.03494, 0.08, 0.0437, 0.08, 0.062093263, 0.03612, 0.04774, 0.03612, 0.0458, 0.03884, 0.0526, 0.0429, 0.0526, 0.0429, 0.040433573, 0.08, 0.0369, 0.04968, 0.04078, 0.0429, 0.060255911, 0.04, 0.06229954, 0.04, 0.04211434, 0.060089947, 0.03204, 0.04, 0.03494, 0.03806, 0.08, 0.03418, 0.03612, 0.073129984, 0.03204, 0.040425715, 0.08, 0.03612, 0.05164, 0.073044368, 0.05354, 0.03612, 0.03418, 0.0429, 0.0526, 0.0437, 0.08, 0.04968, 0.0429, 0.0429, 0.03494, 0.05744, 0.03418, 0.062083165, 0.03204, 0.08, 0.08, 0.03494, 0.03494, 0.03418, 0.0437, 0.040589165, 0.0369, 0.04, 0.040569407, 0.040589165, 0.060039655, 0.05162, 0.08, 0.08, 0.03204, 0.040450861, 0.08, 0.08, 0.08, 0.03204, 0.0369, 0.041924388, 0.05164, 0.040411346, 0.08, 0.08, 0.08, 0.040589165, 0.0369, 0.060089947, 0.08, ...
# Total revenue: 3579531.5156752225

# %%
feasible_loans['optimal_fee'] = optimal_fees

# Categorize loans into amount tiers
bins = [1000, 6000, 12000, 18000, 25000, 32000, 40000]
labels = ['1K-5K', '6K-11K', '12K-17K', '18K-24K', '25K-31K', '32K-40K']
feasible_loans['loan_amount_tier'] = pd.cut(feasible_loans['loan_amount'], bins=bins, labels=labels, right=False)

# Calculate profit (fee revenue) per loan
feasible_loans['profit'] = (feasible_loans['optimal_fee'] * feasible_loans['loan_amount'])

# %%
print(loans['grade'].value_counts())
print(feasible_loans['grade'].value_counts())
# Out:
# grade
# B    3037
# C    2653
# A    2459
# D    1446
# E     335
# F      58
# G      12
# Name: count, dtype: int64
# grade
# C    1921
# D    1390
# E     313
# F      56
# G      12
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(data=feasible_loans, x='grade', y='optimal_fee', order=['A', 'B', 'C', 'D', 'E', 'F', 'G'])
plt.title('Optimal Origination Fees by Loan Grade')
plt.xlabel('Loan Grade')
plt.ylabel('Origination Fee (%)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Aggregate profit by grade
profit_by_tier = feasible_loans.groupby('grade')['profit'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(data=profit_by_tier, x='grade', y='profit', palette='Blues_d')
plt.title('Total Profit by Loan Grade')
plt.xlabel('Loan Grade')
plt.ylabel('Total Profit ($)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add value labels
for index, row in profit_by_tier.iterrows():
    plt.text(index, row['profit'], f"${row['profit']:,.0f}", 
             ha='center', va='bottom', fontweight='bold')

plt.show()
# Out:
# /var/folders/_4/t03mdfy94ts0ylt8cw0q1bp00000gn/T/ipykernel_32176/3891585640.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=profit_by_tier, x='grade', y='profit', palette='Blues_d')
